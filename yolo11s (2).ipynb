# %%
# !pip uninstall -y numpy scipy albumentations scikit-image
# !pip install numpy==1.26.4 scipy==1.11.4 albumentations==1.3.1 scikit-image==0.21.0

# %%
# !pip install ultralytics --no-deps
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.229-py3-none-any.whl.metadata (37 kB)
# Downloading ultralytics-8.3.229-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: ultralytics
# Successfully installed ultralytics-8.3.229

# %%
import os
import random
import shutil
import stat
import numpy as np
import torch
import cv2
import albumentations as A
from ultralytics import YOLO

# =========================================================
# ✅ Reproducibility: Set random seeds (consistent everywhere)
# =========================================================
def set_seed(seed=42):
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    # Ensure deterministic operations on GPU (may slow training)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)
print(f"✅ Random seed set to {SEED}")

# =========================================================
# Versions
# =========================================================
print("Albumentations:", A.__version__)
print("Torch:", torch.__version__)

# =========================================================
# Paths & dataset writability handling (Kaggle-safe)
# =========================================================
orig_data_yaml = "/kaggle/input/violenceweapondetection/data.yaml"
# Destination (writable) dataset root for faster caching / saving
writable_dataset_root = "/kaggle/working/violenceweapondetection"

def ensure_writable_dataset(src_yaml_path, dst_root):
    """
    If the dataset path is not writable (e.g. /kaggle/input), copy dataset to a writable location.
    Returns path to data.yaml to use (and creates dst_root if needed).
    """
    src_root = os.path.dirname(src_yaml_path)
    # If src is already writable, return original
    try:
        testfile = os.path.join(src_root, ".writetest")
        with open(testfile, "w") as f:
            f.write("test")
        os.remove(testfile)
        print("Dataset directory is writable — no copy needed.")
        return src_yaml_path
    except Exception:
        print("Dataset directory not writable — copying to a writable location (this may take time).")
    # Copy (skip if already copied)
    if os.path.exists(dst_root):
        print("Writable copy already exists.")
    else:
        shutil.copytree(src_root, dst_root)
        # make sure permissions allow write
        for root, dirs, files in os.walk(dst_root):
            for d in dirs:
                os.chmod(os.path.join(root, d), stat.S_IRWXU | stat.S_IRGRP | stat.S_IXGRP)
            for f in files:
                os.chmod(os.path.join(root, f), stat.S_IRUSR | stat.S_IWUSR)
        print(f"Copied dataset to {dst_root}")
    # update yaml path (same filename inside new root)
    return os.path.join(dst_root, os.path.basename(src_yaml_path))

data_yaml = ensure_writable_dataset(orig_data_yaml, writable_dataset_root)

# =========================================================
# ✅ Custom CCTV Augmentation Pipeline (Albumentations)
# NOTE: remove ToTensorV2 — let Ultralytics dataset handle conversion
# =========================================================
train_transform = A.Compose([
    # Geometric transformations
    A.RandomResizedCrop(height=640, width=640, scale=(0.7, 1.0), ratio=(0.75, 1.33), p=1.0),
    A.HorizontalFlip(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.1, rotate_limit=15,
                       border_mode=cv2.BORDER_CONSTANT, p=0.8),

    # Brightness / contrast / color (CCTV-like)
    A.RandomBrightnessContrast(p=0.7),
    A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=15, p=0.6),
    A.CLAHE(clip_limit=2.0, tile_grid_size=(8, 8), p=0.4),

    # Blur / Noise (CCTV noise)
    A.MotionBlur(p=0.3),
    A.GaussianBlur(blur_limit=(3, 5), p=0.3),
    A.GaussNoise(var_limit=(5, 25), p=0.3),

    # Occlusions
    A.CoarseDropout(max_holes=8, max_height=32, max_width=32, fill_value=0, p=0.4),
], p=1.0)

# =========================================================
# ✅ Load YOLOv11s Pretrained Model
# =========================================================
model = YOLO("yolo11s.pt")  # will auto-download if not exists

# Force Ultralytics to not use internal 'randaugment' that may call ImageCompression with unsupported args
# (this avoids the ImageCompression.__init__() got unexpected keyword 'quality_range' warning)
model.overrides["auto_augment"] = None

# YOLO augmentation controls (kept)
model.overrides["augment"] = True
model.overrides["rect"] = False
model.overrides["mosaic"] = 0.3
model.overrides["mixup"] = 0.2
model.overrides["copy_paste"] = 0.0

# =========================================================
# HOOK Albumentations into YOLO dataset
# Use on_fit_start so dataset exists and we can set transforms before epochs run
# =========================================================
def custom_dataloader_hook(trainer):
    """
    trainer.train_loader.dataset is expected to be the Ultralytics dataset instance.
    Setting dataset.transforms to an Albumentations Compose that accepts/returns numpy arrays
    (Ultralytics will handle conversion to tensors internally).
    """
    try:
        ds = trainer.train_loader.dataset
        ds.transforms = train_transform
        print("✅ Injected custom Albumentations transforms into dataset.")
    except Exception as e:
        # In case API differs, print the error so you can adjust.
        print("⚠️ Could not inject transforms into dataset (exception):", e)

# Register callback
model.add_callback("on_fit_start", custom_dataloader_hook)

# =========================================================
# TRAIN
# - Pass seed explicitly
# - disable internal auto_augment via overrides above
# =========================================================
save_dir = "/kaggle/working/yolov11s_cctv_aug_runs"

results = model.train(
    data=data_yaml,
    epochs=300,
    imgsz=640,
    batch=16,
    device=0 if torch.cuda.is_available() else 'cpu',
    project=save_dir,
    name="yolov11s_cctv_aug",
    workers=2,

    # Repro / hyperparams
    seed=SEED,
    deterministic=True,

    # Best CCTV hyperparameters
    lr0=0.0025,
    lrf=0.01,
    optimizer="AdamW",
    momentum=0.90,
    weight_decay=0.0004,
    warmup_epochs=3.0,
    patience=25,

    mosaic=0.3,
    mixup=0.2,
    copy_paste=0.0,
    augment=True,

    val=True,
    pretrained=True,
    verbose=True,
    exist_ok=True,

    save=True
)

# =========================================================
# EVALUATION
# =========================================================
metrics = model.val()
print("Validation Metrics:")
try:
    print(f"mAP50-95: {metrics.box.map:.4f}")
    print(f"Precision: {metrics.box.pr:.4f}")
    print(f"Recall: {metrics.box.re:.4f}")
except Exception:
    # If metrics object differs, print repr for inspection
    print("Metrics object:", repr(metrics))

# =========================================================
# EXPORT ZIP FILE (Optional)
# =========================================================
shutil.make_archive(save_dir, 'zip', save_dir)
print("✅ Training + Augmentation + Export completed successfully!")
# Out:
# ✅ Random seed set to 42
# Albumentations: 1.3.1
# Torch: 2.6.0+cu124
# Dataset directory not writable — copying to a writable location (this may take time).
# Copied dataset to /kaggle/working/violenceweapondetection
# Ultralytics 8.3.229 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=True, auto_augment=None, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/violenceweapondetection/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=300, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0025, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo11s.pt, momentum=0.9, mosaic=0.3, multi_scale=False, name=yolov11s_cctv_aug, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolov11s_cctv_aug_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolov11s_cctv_aug_runs/yolov11s_cctv_aug, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0004, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820182  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,566 parameters, 9,428,550 gradients
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1197.0±562.1 MB/s, size: 43.0 KB)
# train: Scanning /kaggle/working/violenceweapondetection/train/labels... 7720 images, 1837 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7720/7720 1.5Kit/s 5.3s<0.0s
# train: New cache created: /kaggle/working/violenceweapondetection/train/labels.cache
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 242.7±153.3 MB/s, size: 38.1 KB)
# val: Scanning /kaggle/working/violenceweapondetection/valid/labels... 948 images, 205 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 948/948 1.4Kit/s 0.7s0.1s
# val: New cache created: /kaggle/working/violenceweapondetection/valid/labels.cache
# Plotting labels to /kaggle/working/yolov11s_cctv_aug_runs/yolov11s_cctv_aug/labels.jpg...
# optimizer: AdamW(lr=0.0025, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0004), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/yolov11s_cctv_aug_runs/yolov11s_cctv_aug
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300      5.01G      2.447      3.486      2.483          9        640: 100% ━━━━━━━━━━━━ 483/483 3.6it/s 2:15<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.3it/s 7.0s0.2s
#                    all        948        806     0.0877     0.0485      0.026    0.00851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300      5.06G      2.455      3.454       2.57          7        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:11<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.243     0.0887     0.0677     0.0216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300       5.1G      2.367      3.326      2.454         10        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806       0.45      0.125     0.0759     0.0262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300      5.12G      2.288      3.152      2.367          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.3it/s 6.9s0.2s
#                    all        948        806      0.192      0.163      0.111     0.0391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300      5.18G      2.239       3.04      2.274         16        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.9s0.2s
#                    all        948        806       0.32      0.232      0.149     0.0576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300      5.22G      2.142      2.914      2.218         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.3it/s 7.0s0.2s
#                    all        948        806      0.335      0.218      0.169     0.0672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300      5.26G      2.128      2.883      2.196          9        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.3it/s 7.0s0.2s
#                    all        948        806      0.289      0.243      0.203     0.0927
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300      5.29G      2.092      2.749       2.15         11        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.9s0.2s
#                    all        948        806        0.3      0.278        0.2     0.0833
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300      5.34G      2.059      2.712      2.107          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.349      0.255       0.21     0.0861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300      5.38G       2.05      2.677      2.085         10        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.372      0.321      0.277      0.124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300      5.42G      2.015      2.623      2.074         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.9s0.2s
#                    all        948        806      0.386      0.358      0.295      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300      5.77G      2.005      2.564      2.046          8        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.422      0.359      0.323      0.148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300      5.83G      1.975      2.509      2.023         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.9s0.2s
#                    all        948        806      0.404      0.354      0.314       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300      5.86G      1.967      2.496      2.021          9        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.3it/s 6.9s0.2s
#                    all        948        806       0.39      0.382      0.338      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/300      5.91G       1.95      2.463      1.988          7        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.476      0.396      0.357      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/300      5.93G      1.932      2.428      1.967         11        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.478      0.411      0.405      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/300      5.99G      1.917      2.389      1.966         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.442      0.424      0.403      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/300      6.02G      1.916      2.386       1.96          6        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.466      0.422      0.403      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/300      6.06G      1.905      2.342       1.95          6        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.416      0.407      0.369      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/300      6.08G      1.896      2.323      1.936          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.493        0.4      0.392      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/300      6.14G      1.889      2.293      1.927          5        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.9s0.2s
#                    all        948        806      0.499      0.482      0.458      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/300      6.18G      1.877       2.28      1.906         12        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.532      0.453      0.452      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/300      6.22G      1.855      2.234      1.893          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.3it/s 6.9s0.2s
#                    all        948        806       0.53      0.481      0.473      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/300      6.25G       1.85      2.203      1.894          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.9s0.2s
#                    all        948        806      0.542      0.471      0.494      0.242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/300       6.3G      1.837      2.197      1.874         11        640: 100% ━━━━━━━━━━━━ 483/483 3.7it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806       0.48      0.467       0.43      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/300      6.34G      1.815       2.14      1.864         16        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.3it/s 6.9s0.2s
#                    all        948        806      0.532      0.495      0.472       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/300      6.38G      1.805      2.136      1.857          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.9s0.2s
#                    all        948        806      0.627      0.487       0.53       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/300       6.4G      1.824      2.112      1.863          6        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.613      0.499      0.527      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/300      6.46G       1.79      2.099      1.843         13        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.597       0.49      0.527      0.265
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/300       6.5G      1.797      2.074      1.828          7        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.598      0.512      0.528      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/300      6.54G      1.794      2.072      1.839          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806       0.64      0.493       0.54      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/300      6.56G      1.766      2.041      1.812         13        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.9s0.2s
#                    all        948        806        0.6      0.514      0.522      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/300      6.62G       1.78       2.03      1.815         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.618      0.531      0.546       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/300      6.66G      1.759      2.017        1.8         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.601       0.53      0.555      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/300       6.7G      1.758      1.982      1.807         13        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.661      0.551      0.585      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/300      6.72G      1.746      1.978      1.797          7        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.614      0.551      0.565      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/300      6.78G      1.744      1.968        1.8         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806       0.63      0.552      0.576      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/300      6.82G      1.735      1.945       1.78         19        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.7s0.2s
#                    all        948        806      0.668      0.574       0.59        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/300      6.86G      1.715      1.913      1.763          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.637       0.55      0.568      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/300      6.88G      1.727      1.909      1.758          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.676      0.566      0.593      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/300      6.94G      1.709      1.883      1.755         13        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.668      0.563      0.603       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/300      6.98G      1.702      1.859      1.742         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.626      0.608       0.61      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/300      7.02G       1.71      1.861      1.751         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.644      0.583      0.622      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/300      7.04G      1.698      1.861      1.746         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.691      0.585      0.612      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/300       7.1G      1.691      1.822      1.734         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.662      0.611      0.628      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/300      7.14G      1.704      1.839      1.749          5        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.665      0.602       0.63      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/300      7.18G       1.69      1.835      1.734          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.712      0.593      0.636      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/300       7.2G      1.656      1.781      1.704          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.5s0.2s
#                    all        948        806      0.687      0.611      0.644      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/300      7.26G      1.681      1.794      1.724          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.715      0.603      0.639       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/300       7.3G      1.671      1.778      1.713         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.743      0.603      0.649       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/300      7.34G      1.661      1.743      1.709         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.703      0.595      0.647      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/300      7.36G      1.663      1.765      1.707          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.721      0.616      0.657       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/300      4.71G      1.645      1.729      1.694         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.722       0.62      0.661      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/300      5.47G      1.651      1.713      1.691          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806       0.71      0.623      0.679      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/300      5.47G      1.621      1.673       1.67          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.722      0.632       0.68      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/300      5.47G      1.631       1.71       1.67          6        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806       0.72      0.633      0.682      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/300      5.47G      1.637      1.688      1.679         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.721      0.649      0.691      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/300      5.47G      1.607      1.659       1.66         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.734       0.63      0.683      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/300      5.47G      1.617      1.652      1.672         14        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.745      0.636      0.685      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/300      5.47G      1.601      1.667       1.66          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.778      0.628      0.697      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/300      5.47G      1.601      1.642      1.647          7        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.741      0.637       0.69      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/300       5.5G      1.593       1.61      1.647         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.749      0.625      0.688      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/300      5.54G      1.594      1.608      1.647         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.772       0.64      0.704      0.384
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/300      5.56G      1.582      1.586      1.622          5        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.752       0.64      0.704      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/300      5.62G       1.58      1.596      1.634         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.739      0.648      0.701      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/300      5.66G      1.595        1.6      1.637         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.765      0.641      0.709       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/300       5.7G      1.577      1.567      1.632          6        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.5s0.2s
#                    all        948        806       0.76      0.626      0.703      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/300      5.72G      1.576      1.564       1.63          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.791      0.636      0.715      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/300      5.78G      1.571       1.54      1.621          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.787      0.643       0.71      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/300      5.81G      1.568      1.536      1.626         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.5s0.2s
#                    all        948        806      0.781      0.647      0.722      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/300      5.86G      1.565      1.543      1.612         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.773      0.655      0.731      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/300      5.88G       1.56       1.53      1.605         13        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.788       0.64      0.727      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/300      5.94G      1.565      1.528      1.612         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.5s0.2s
#                    all        948        806      0.785      0.646       0.73      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/300      5.97G       1.56      1.521      1.599          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.793      0.666      0.737      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/300      6.01G      1.548      1.505      1.597         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806        0.8      0.641      0.724      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/300      6.04G      1.541      1.487      1.587         14        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.789      0.656      0.727      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/300      6.09G      1.546       1.49      1.588         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806       0.79      0.658      0.734      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/300      6.13G      1.543      1.477      1.596          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.791      0.662      0.735      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/300      6.17G      1.526      1.474       1.59         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.797      0.663      0.742      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/300       6.2G      1.536      1.466      1.585          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.795      0.669      0.746      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/300      6.25G      1.521      1.446      1.575         16        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.784      0.682      0.743      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/300      6.29G      1.524      1.446      1.574         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:07<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.793      0.673      0.745      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/300      6.33G      1.513       1.44      1.569         11        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.804      0.681      0.743      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/300      6.35G      1.493      1.406      1.553         15        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.789      0.683      0.753      0.415
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/300      6.41G      1.508       1.42      1.567         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.802      0.685      0.752      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/300      6.45G      1.519      1.434      1.569          8        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.802      0.689      0.751      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/300      6.49G      1.479      1.398      1.546          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:09<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.4it/s 6.8s0.2s
#                    all        948        806      0.798      0.683      0.747      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/300      6.51G      1.476      1.415      1.553         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.781      0.695      0.756       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/300      6.57G      1.486      1.398      1.553         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.799      0.697      0.756      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/300      6.61G      1.476      1.377      1.533         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.805      0.689      0.758      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/300      6.65G      1.492      1.398      1.554          5        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.804      0.691      0.758      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/300      6.67G      1.469      1.349      1.527         13        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.803      0.697       0.76      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/300      6.73G      1.486      1.385      1.539         12        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.799      0.691      0.759      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/300      6.77G      1.467      1.351      1.523         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806       0.82      0.676      0.761      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/300      6.81G      1.455      1.347      1.523         15        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.783      0.697      0.762      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/300      6.83G      1.462      1.346      1.524         10        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.6it/s 6.6s0.2s
#                    all        948        806      0.771      0.714      0.767      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/300      6.89G      1.449      1.322      1.511          9        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.813       0.67      0.764      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/300      6.93G       1.45       1.34      1.524          6        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.7s0.2s
#                    all        948        806      0.783      0.693      0.767      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/300      6.97G      1.461      1.328      1.523          7        640: 100% ━━━━━━━━━━━━ 483/483 3.8it/s 2:08<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 30/30 4.5it/s 6.6s0.2s
#                    all        948        806      0.801      0.682      0.766      0.434
#
# ...
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.29554,     0.29554,     0.37032, ...,           1,           1,           1],
#        [    0.16257,     0.16258,     0.22915, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[      0.945,       0.945,      0.9375, ...,           0,           0,           0],
#        [    0.87931,     0.87931,     0.86946, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: 0.48524305005679597
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.59078,      0.3797])
# names: {0: 'Violence Event', 1: 'Weaponized Event'}
# nt_per_class: array([400, 406])
# nt_per_image: array([390, 355])
# results_dict: {'metrics/precision(B)': 0.8320323324970993, 'metrics/recall(B)': 0.7707692004234644, 'metrics/mAP50(B)': 0.8320991887956077, 'metrics/mAP50-95(B)': 0.48524305005679597, 'fitness': 0.48524305005679597}
# save_dir: PosixPath('/kaggle/working/runs/detect/val')
# speed: {'preprocess': 1.0387418597058233, 'inference': 8.866530338612696, 'loss': 0.0005719536030763281, 'postprocess': 0.8565075495502595}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}
# task: 'detect'
# ✅ Training + Augmentation + Export completed successfully!
